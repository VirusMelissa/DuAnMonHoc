# %% [markdown]
# <p style="color: red; font-size: 30px; text-align: center; font-weight: bold">
#     Trò Chơi 'Búa' - 'Kéo' - 'Bao' quyết định thắng khi hơn 2 điểm
# </p>

# %%
import random as r

def play_game(nguoi_choi):
    sovongchoi = 0
    nguoi_loai = []
    
    while len(nguoi_choi) > 1:
        sovongchoi += 1
        print('--------------------------------------')
        print("Vòng:", sovongchoi)
        
        cap_ngaunhien = r.sample(nguoi_choi, 2)
        nguoi1, nguoi2 = cap_ngaunhien
        
        diemso_N1 = 0
        diemso_N2 = 0
        luotchoi = 0
        
        print("\n")
        
        while True:
            luotchoi += 1
            print("\nLượt: {0} của cặp {1} và {2}".format(luotchoi, nguoi1, nguoi2))
            nguoi1_chon = r.choice(['Búa', 'Kéo', 'Bao'])
            nguoi2_chon = r.choice(['Búa', 'Kéo', 'Bao'])
            
            print("Người chơi", nguoi1, "ra:", nguoi1_chon)
            print("Người chơi", nguoi2, "ra:", nguoi2_chon)
            
            if nguoi1_chon == nguoi2_chon:
                diemso_N1 += 1
                diemso_N2 += 1
                print("Hòa")
            elif (nguoi1_chon == 'Búa' and nguoi2_chon == 'Kéo') or \
                (nguoi1_chon == 'Kéo' and nguoi2_chon == 'Bao') or \
                (nguoi1_chon == 'Bao' and nguoi2_chon == 'Búa'):
                diemso_N1 += 1
                print("Người chơi", nguoi1, "thắng lượt này")
            else:
                diemso_N2 += 1
                print("Người chơi", nguoi2, "thắng lượt này")
            
            print("Điểm số: {0} - {1} | {2} - {3}".format(nguoi1, diemso_N1, nguoi2, diemso_N2))
        
            if diemso_N1 == (diemso_N2 + 2):
                nguoi_loai.append(nguoi2)
                nguoi_choi.remove(nguoi2)
                print("\n***Người chơi", nguoi1, "thắng cặp chơi này***")
                print("Danh sách người bị loại: ", nguoi_loai)
                break
            if diemso_N2 == (diemso_N1 + 2):
                nguoi_loai.append(nguoi1)
                nguoi_choi.remove(nguoi1)
                print("\n***Người chơi", nguoi2, "thắng cặp chơi này***")
                print("Danh sách người bị loại: ", nguoi_loai)
                break

                
    print("\nNgười chơi", nguoi_choi[0], "là người chiến thắng cuối cùng!")


# Nhập tổng số người chơi từ 8-20
tong_so_nguoi_choi = int(input("Nhập tổng số người chơi (8-20): "))
while tong_so_nguoi_choi < 8 or tong_so_nguoi_choi > 20:
    print("Vui lòng nhập số người chơi từ 8 đến 20.")
    tong_so_nguoi_choi = int(input("Nhập tổng số người chơi (8-20): "))

# Tạo danh sách các người chơi
nguoichoi = []
for i in range(1, tong_so_nguoi_choi + 1):
    nguoichoi.append("P" + str(i))

# Chơi game
play_game(nguoichoi)

# %% [markdown]
# <br><br>
# <p style="color: red; font-size: 30px; text-align: center; font-weight: bold">
#     Trò Chơi 'Búa' - 'Kéo' - 'Bao' quyết định thắng khi hơn 1 điểm
# </p>

# %%
import random as r

def play_game(nguoi_choi):
    sovongchoi = 0
    nguoi_loai = []
    
    while len(nguoi_choi) > 1:
        sovongchoi += 1
        print('--------------------------------------')
        print("Vòng:", sovongchoi)
        
        cap_ngaunhien = r.sample(nguoi_choi, 2)
        nguoi1, nguoi2 = cap_ngaunhien
        
        diemso_N1 = 0
        diemso_N2 = 0
        luotchoi = 0
        
        print("\n")
        
        while True:
            luotchoi += 1
            print("\nLượt: {0} của cặp {1} và {2}".format(luotchoi, nguoi1, nguoi2))
            nguoi1_chon = r.choice(['Búa', 'Kéo', 'Bao'])
            nguoi2_chon = r.choice(['Búa', 'Kéo', 'Bao'])
            
            print("Người chơi", nguoi1, "ra:", nguoi1_chon)
            print("Người chơi", nguoi2, "ra:", nguoi2_chon)
            
            if nguoi1_chon == nguoi2_chon:
                diemso_N1 += 1
                diemso_N2 += 1
                print("Hòa")
            elif (nguoi1_chon == 'Búa' and nguoi2_chon == 'Kéo') or \
                (nguoi1_chon == 'Kéo' and nguoi2_chon == 'Bao') or \
                (nguoi1_chon == 'Bao' and nguoi2_chon == 'Búa'):
                diemso_N1 += 1
                print("Người chơi", nguoi1, "thắng lượt này")
            else:
                diemso_N2 += 1
                print("Người chơi", nguoi2, "thắng lượt này")
            
            print("Điểm số: {0} - {1} | {2} - {3}".format(nguoi1, diemso_N1, nguoi2, diemso_N2))
        
            if diemso_N1 == (diemso_N2 + 1):
                nguoi_loai.append(nguoi2)
                nguoi_choi.remove(nguoi2)
                print("\n***Người chơi", nguoi1, "thắng cặp chơi này***")
                print("Danh sách người bị loại: ", nguoi_loai)
                break
            if diemso_N2 == (diemso_N1 + 1):
                nguoi_loai.append(nguoi1)
                nguoi_choi.remove(nguoi1)
                print("\n***Người chơi", nguoi2, "thắng cặp chơi này***")
                print("Danh sách người bị loại: ", nguoi_loai)
                break

                
    print("\nNgười chơi", nguoi_choi[0], "là người chiến thắng cuối cùng!")


# Nhập tổng số người chơi từ 8-20
tong_so_nguoi_choi = int(input("Nhập tổng số người chơi (8-20): "))
while tong_so_nguoi_choi < 8 or tong_so_nguoi_choi > 20:
    print("Vui lòng nhập số người chơi từ 8 đến 20.")
    tong_so_nguoi_choi = int(input("Nhập tổng số người chơi (8-20): "))

# Tạo danh sách các người chơi
nguoichoi = []
for i in range(1, tong_so_nguoi_choi + 1):
    nguoichoi.append("P" + str(i))

# Chơi game
play_game(nguoichoi)
# Out:
# Nhập tổng số người chơi (8-20): 18
# --------------------------------------
# Vòng: 1
#
#
#
# Lượt: 1 của cặp P12 và P1
# Người chơi P12 ra: Búa
# Người chơi P1 ra: Bao
# Người chơi P1 thắng lượt này
# Điểm số: P12 - 0 | P1 - 1
#
# ***Người chơi P1 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12']
# --------------------------------------
# Vòng: 2
#
#
#
# Lượt: 1 của cặp P11 và P5
# Người chơi P11 ra: Bao
# Người chơi P5 ra: Kéo
# Người chơi P5 thắng lượt này
# Điểm số: P11 - 0 | P5 - 1
#
# ***Người chơi P5 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11']
# --------------------------------------
# Vòng: 3
#
#
#
# Lượt: 1 của cặp P9 và P14
# Người chơi P9 ra: Búa
# Người chơi P14 ra: Bao
# Người chơi P14 thắng lượt này
# Điểm số: P9 - 0 | P14 - 1
#
# ***Người chơi P14 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9']
# --------------------------------------
# Vòng: 4
#
#
#
# Lượt: 1 của cặp P10 và P7
# Người chơi P10 ra: Kéo
# Người chơi P7 ra: Búa
# Người chơi P7 thắng lượt này
# Điểm số: P10 - 0 | P7 - 1
#
# ***Người chơi P7 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10']
# --------------------------------------
# Vòng: 5
#
#
#
# Lượt: 1 của cặp P18 và P3
# Người chơi P18 ra: Búa
# Người chơi P3 ra: Kéo
# Người chơi P18 thắng lượt này
# Điểm số: P18 - 1 | P3 - 0
#
# ***Người chơi P18 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3']
# --------------------------------------
# Vòng: 6
#
#
#
# Lượt: 1 của cặp P18 và P13
# Người chơi P18 ra: Kéo
# Người chơi P13 ra: Kéo
# Hòa
# Điểm số: P18 - 1 | P13 - 1
#
# Lượt: 2 của cặp P18 và P13
# Người chơi P18 ra: Kéo
# Người chơi P13 ra: Kéo
# Hòa
# Điểm số: P18 - 2 | P13 - 2
#
# Lượt: 3 của cặp P18 và P13
# Người chơi P18 ra: Bao
# Người chơi P13 ra: Búa
# Người chơi P18 thắng lượt này
# Điểm số: P18 - 3 | P13 - 2
#
# ***Người chơi P18 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13']
# --------------------------------------
# Vòng: 7
#
#
#
# Lượt: 1 của cặp P1 và P17
# Người chơi P1 ra: Kéo
# Người chơi P17 ra: Búa
# Người chơi P17 thắng lượt này
# Điểm số: P1 - 0 | P17 - 1
#
# ***Người chơi P17 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1']
# --------------------------------------
# Vòng: 8
#
#
#
# Lượt: 1 của cặp P6 và P14
# Người chơi P6 ra: Búa
# Người chơi P14 ra: Búa
# Hòa
# Điểm số: P6 - 1 | P14 - 1
#
# Lượt: 2 của cặp P6 và P14
# Người chơi P6 ra: Búa
# Người chơi P14 ra: Bao
# Người chơi P14 thắng lượt này
# Điểm số: P6 - 1 | P14 - 2
#
# ***Người chơi P14 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6']
# --------------------------------------
# Vòng: 9
#
#
#
# Lượt: 1 của cặp P5 và P16
# Người chơi P5 ra: Kéo
# Người chơi P16 ra: Kéo
# Hòa
# Điểm số: P5 - 1 | P16 - 1
#
# Lượt: 2 của cặp P5 và P16
# Người chơi P5 ra: Kéo
# Người chơi P16 ra: Kéo
# Hòa
# Điểm số: P5 - 2 | P16 - 2
#
# Lượt: 3 của cặp P5 và P16
# Người chơi P5 ra: Búa
# Người chơi P16 ra: Kéo
# Người chơi P5 thắng lượt này
# Điểm số: P5 - 3 | P16 - 2
#
# ***Người chơi P5 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16']
# --------------------------------------
# Vòng: 10
#
#
#
# Lượt: 1 của cặp P15 và P5
# Người chơi P15 ra: Búa
# Người chơi P5 ra: Kéo
# Người chơi P15 thắng lượt này
# Điểm số: P15 - 1 | P5 - 0
#
# ***Người chơi P15 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5']
# --------------------------------------
# Vòng: 11
#
#
#
# Lượt: 1 của cặp P4 và P7
# Người chơi P4 ra: Bao
# Người chơi P7 ra: Kéo
# Người chơi P7 thắng lượt này
# Điểm số: P4 - 0 | P7 - 1
#
# ***Người chơi P7 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4']
# --------------------------------------
# Vòng: 12
#
#
#
# Lượt: 1 của cặp P15 và P18
# Người chơi P15 ra: Kéo
# Người chơi P18 ra: Búa
# Người chơi P18 thắng lượt này
# Điểm số: P15 - 0 | P18 - 1
#
# ***Người chơi P18 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15']
# --------------------------------------
# Vòng: 13
#
#
#
# Lượt: 1 của cặp P14 và P7
# Người chơi P14 ra: Kéo
# Người chơi P7 ra: Búa
# Người chơi P7 thắng lượt này
# Điểm số: P14 - 0 | P7 - 1
#
# ***Người chơi P7 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15', 'P14']
# --------------------------------------
# Vòng: 14
#
#
#
# Lượt: 1 của cặp P2 và P17
# Người chơi P2 ra: Kéo
# Người chơi P17 ra: Bao
# Người chơi P2 thắng lượt này
# Điểm số: P2 - 1 | P17 - 0
#
# ***Người chơi P2 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15', 'P14', 'P17']
# --------------------------------------
# Vòng: 15
#
#
#
# Lượt: 1 của cặp P7 và P8
# Người chơi P7 ra: Kéo
# Người chơi P8 ra: Bao
# Người chơi P7 thắng lượt này
# Điểm số: P7 - 1 | P8 - 0
#
# ***Người chơi P7 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15', 'P14', 'P17', 'P8']
# --------------------------------------
# Vòng: 16
#
#
#
# Lượt: 1 của cặp P18 và P7
# Người chơi P18 ra: Búa
# Người chơi P7 ra: Bao
# Người chơi P7 thắng lượt này
# Điểm số: P18 - 0 | P7 - 1
#
# ***Người chơi P7 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15', 'P14', 'P17', 'P8', 'P18']
# --------------------------------------
# Vòng: 17
#
#
#
# Lượt: 1 của cặp P7 và P2
# Người chơi P7 ra: Bao
# Người chơi P2 ra: Kéo
# Người chơi P2 thắng lượt này
# Điểm số: P7 - 0 | P2 - 1
#
# ***Người chơi P2 thắng cặp chơi này***
# Danh sách người bị loại:  ['P12', 'P11', 'P9', 'P10', 'P3', 'P13', 'P1', 'P6', 'P16', 'P5', 'P4', 'P15', 'P14', 'P17', 'P8', 'P18', 'P7']
#
# Người chơi P2 là người chiến thắng cuối cùng!
