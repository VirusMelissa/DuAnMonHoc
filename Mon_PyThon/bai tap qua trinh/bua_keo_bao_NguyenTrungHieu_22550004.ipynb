# %%
import random as r

#số lần người hoặc máy thắng
sl_nguoithang = 0; sl_maythang = 0; solanchoi = 0
a = 'Búa'
b = 'Kéo'
c = 'Bao'

while True:
    #lặp số lần chơi đến khi người hoặc máy chênh lệch 2 lần thắng
    solanchoi += 1
    print('--------------------------------------')
    print("Lần:",solanchoi)
    
    
    #người ra gì và máy ra auto
    nguoi = input("Bạn nhập: ")
    may = r.choice(['Kéo','Búa','Bao'])
    
    #kiểm tra người dùng nhập đúng Kéo Búa Bao hay sai
    while nguoi not in ['Kéo','Búa','Bao']:
        print("Bạn chỉ được nhập 'Kéo', 'Búa', 'Bao'")
        nguoi = input("Bạn hãy nhập lại: ")
    
    #xuất kết quả người và máy chọn
    print("\nNgười ra: ", nguoi)
    print("Máy ra: ", may)

    if nguoi == 'Búa':
        if may == a:
            sl_nguoithang += 1
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Hòa")
        elif may == b:
            sl_nguoithang += 1
            print("Lần",solanchoi,"kết quả: Người thắng")
        else:
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Máy thắng")
            
    elif nguoi == 'Kéo':
        if may == a:
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Máy thắng")
        elif may == b:
            sl_nguoithang += 1
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Hòa")
        else:
            sl_nguoithang += 1
            print("Lần",solanchoi,"kết quả: Người thắng")
            
    elif nguoi == 'Bao':
        if may == a:
            sl_nguoithang += 1
            print("Lần",solanchoi,"kết quả: Người thắng")
        elif may == b:
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Máy thắng")
        else:
            sl_nguoithang += 1
            sl_maythang += 1
            print("Lần",solanchoi,"kết quả: Hòa")

    print("\nĐiểm số người chơi: ",sl_nguoithang)
    print("Điểm số của máy: ",sl_maythang)

    if sl_nguoithang == (sl_maythang + 2):
        print("=>Người thắng")
        break
    elif sl_maythang == (sl_nguoithang + 2):
        print("=>Máy thắng")
        break
# Out:
# --------------------------------------
# Lần: 1
# Bạn nhập: búa
# Bạn chỉ được nhập 'Kéo', 'Búa', 'Bao'
# Bạn hãy nhập lại: keo
# Bạn chỉ được nhập 'Kéo', 'Búa', 'Bao'
# Bạn hãy nhập lại: bao
# Bạn chỉ được nhập 'Kéo', 'Búa', 'Bao'
# Bạn hãy nhập lại: Kéo
#
# Người ra:  Kéo
# Máy ra:  Bao
# Lần 1 Kết quả: Người thắng
#
# Điểm số người chơi:  1
# Điểm số của máy:  0
# --------------------------------------
# Lần: 2
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Kéo
# Lần 2 Kết quả: Hòa
#
# Điểm số người chơi:  2
# Điểm số của máy:  1
# --------------------------------------
# Lần: 3
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Kéo
# Lần 3 Kết quả: Hòa
#
# Điểm số người chơi:  3
# Điểm số của máy:  2
# --------------------------------------
# Lần: 4
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Búa
# Lần 4 Kết quả: Máy thắng
#
# Điểm số người chơi:  3
# Điểm số của máy:  3
# --------------------------------------
# Lần: 5
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Búa
# Lần 5 Kết quả: Máy thắng
#
# Điểm số người chơi:  3
# Điểm số của máy:  4
# --------------------------------------
# Lần: 6
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Kéo
# Lần 6 Kết quả: Hòa
#
# Điểm số người chơi:  4
# Điểm số của máy:  5
# --------------------------------------
# Lần: 7
# Bạn nhập: Kéo
#
# Người ra:  Kéo
# Máy ra:  Búa
# Lần 7 Kết quả: Máy thắng
#
# Điểm số người chơi:  4
# Điểm số của máy:  6
# =>Máy thắng
